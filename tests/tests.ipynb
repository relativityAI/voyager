# %% [markdown]
# # Tests

# %% [markdown]
# Trendlyne scraper

# %%
from src.tools.web_screeners.trendlyne import Trendlyne

tr = Trendlyne()
r = tr.fetch('KEI')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 from src.tools.trendlyne import Trendlyne
#       3 tr = Trendlyne()
# ----> 4 r = tr.fetch('KEI')
#
# File ~/Desktop/Relativity/projects/voyager/src/tools/trendlyne.py:23, in Trendlyne.fetch(self, symbol)
#      21 for i in swot:
#      22     label = i.find('div').get_text().strip()
# ---> 23     data['swot'][label]['score'] = float(i.find('p').get_text().strip())
#      26 href = swot[0].find('a', href=True)['href']
#      27 r = requests.get(href, headers=generate_fake_headers())
#
# KeyError: 'S'

# %%
# Out:
# 1
